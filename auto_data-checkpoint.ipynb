# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# 1.View and call dataset to environment ?

# %%
data = pd.read_csv("C:/Users/admin/Downloads/auto_data.csv")

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# 2.Find info , top 5 records , bottom 5 records ?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.head(5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
data.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %% [markdown]
# 3.Represent Corelation between variables ?

# %%
data.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %%
correlation_matrix=data.corr(numeric_only=True)
print(correlation_matrix)
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.title('correlation Matrix')
plt.show()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.775396     -0.804203 -0.831741      0.420289
# cylinders    -0.775396   1.000000      0.950721  0.896017     -0.505419
# displacement -0.804203   0.950721      1.000000  0.932824     -0.543684
# weight       -0.831741   0.896017      0.932824  1.000000     -0.417457
# acceleration  0.420289  -0.505419     -0.543684 -0.417457      1.000000
# model_year    0.579267  -0.348746     -0.370164 -0.306564      0.288137
# origin        0.563450  -0.562543     -0.609409 -0.581024      0.205873
#
#               model_year    origin
# mpg             0.579267  0.563450
# cylinders      -0.348746 -0.562543
# displacement   -0.370164 -0.609409
# weight         -0.306564 -0.581024
# acceleration    0.288137  0.205873
# model_year      1.000000  0.180662
# origin          0.180662  1.000000

# %% [markdown]
# 4.plot different kinds of graphs for mean value represetation ? (use required headers) ?

# %%
mean_values=data.mean(numeric_only=True)

# %%
mean_values
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model_year        76.010050
# origin             1.572864
# dtype: float64

# %%
mean_values.plot(kind='bar')
plt.xlabel('Variables')
plt.ylabel('Mean Values')
plt.title('Mean Values for Each Variables')
plt.show()

# %%
mean_values.plot(kind='line')
plt.xlabel('Variables')
plt.ylabel('Mean Value')
plt.title('Mean Values for Each Variables over time')
plt.show()

# %% [markdown]
# 5.Draw the pair plot using sns for mpg, weight,orign and with hue origin, set the size to 4 ?

# %%
headers =['mpg','weight','origin']
sns.pairplot(data[headers],hue='origin',height=4)

# %% [markdown]
# 6.identify name where acceleration is greater than 15 and horsepower less than 170 ?

# %%
data['horsepower']=pd.to_numeric(data['horsepower'],errors='coerce')

# %%
data[(data['acceleration']>15)&(data['horsepower']<170)]['name']
# Out:
# 15                  plymouth duster
# 16                       amc hornet
# 17                    ford maverick
# 19     volkswagen 1131 deluxe sedan
# 20                      peugeot 504
#                    ...
# 392                chevrolet camaro
# 393                 ford mustang gl
# 394                       vw pickup
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 211, dtype: object

# %%
data[(data['acceleration']>15)&(data['horsepower']<170)][['name','horsepower','acceleration']]
# Out:
#                              name  horsepower  acceleration
# 15                plymouth duster        95.0          15.5
# 16                     amc hornet        97.0          15.5
# 17                  ford maverick        85.0          16.0
# 19   volkswagen 1131 deluxe sedan        46.0          20.5
# 20                    peugeot 504        87.0          17.5
# ..                            ...         ...           ...
# 392              chevrolet camaro        90.0          17.3
# 393               ford mustang gl        86.0          15.6
# 394                     vw pickup        52.0          24.6
# 396                   ford ranger        79.0          18.6
# 397                    chevy s-10        82.0          19.4
#
# [211 rows x 3 columns]

# %% [markdown]
# 7.Identify how many types of  cylinder vehicles you have ? (GroupBY)

# %%
num_types=data.groupby('cylinders')[['name','cylinders']].nunique()

# %%
num_types
# Out:
#            name  cylinders
# cylinders
# 3             4          1
# 4           161          1
# 5             3          1
# 6            63          1
# 8            82          1

# %%
cylinder_counts=data.groupby('cylinders')['name'].size()
num_of_vehicles=len(cylinder_counts)

# %%
num_of_vehicles
# Out:
# 5

# %% [markdown]
# 8.how many vehicles in every  model_year ?

# %%
vehicle_counts=data.groupby('model_year').size()

# %%
vehicle_counts
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# dtype: int64
