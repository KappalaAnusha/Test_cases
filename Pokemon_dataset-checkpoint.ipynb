# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/admin/Downloads/Pokemon.csv")

# %%
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# find 1st & last 5 rows ?

# %%
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# check the columns for Data Frame?

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Check the shape of the DataFrame (rows, columns)?

# %%
data.shape
# Out:
# (800, 13)

# %% [markdown]
# check statistical information about the dataframe?

# %%
data.describe().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %% [markdown]
# How many Pokémon are legendary?

# %%
data.groupby('Legendary').size()
# Out:
# Legendary
# False    735
# True      65
# dtype: int64

# %% [markdown]
# Legendary Pokémon by type?

# %%
legendary_count_by_type=data[data['Legendary']].groupby('Type_1').size()#fiter the dataset for legendary pokemon by type

legendary_count_by_type
# Out:
# Type_1
# Dark         2
# Dragon      12
# Electric     4
# Fairy        1
# Fire         5
# Flying       2
# Ghost        2
# Grass        3
# Ground       4
# Ice          2
# Normal       2
# Psychic     14
# Rock         4
# Steel        4
# Water        4
# dtype: int64

# %%
data[data['Legendary']]['Type_1'].value_counts()
# Out:
# Psychic     14
# Dragon      12
# Fire         5
# Electric     4
# Water        4
# Rock         4
# Steel        4
# Ground       4
# Grass        3
# Ice          2
# Normal       2
# Ghost        2
# Dark         2
# Flying       2
# Fairy        1
# Name: Type_1, dtype: int64

# %% [markdown]
# Legendary Pokémon by fighter stats?

# %%
 legendary_fighters=data[(data['Legendary']== True)&(data['Attack']>100)&(data['Defense']>100)]#FILTER THE DATASET TO INCLUDE ONLY LEGENDARYPOKEMON WITH FIGHTER STATS
print(legendary_fighters[['Name','Attack','Defense']])
# Out:
#                       Name  Attack  Defense
# 423                Groudon     150      140
# 424  GroudonPrimal Groudon     180      160
# 538                Mesprit     105      105
# 540                 Dialga     120      120
# 543              Regigigas     160      110
# 552                 Arceus     120      120
# 707                 Zekrom     150      120
# 796    DiancieMega Diancie     160      110
# 799              Volcanion     110      120

# %% [markdown]
# Cleaning the dataset

# %%
data.dropna()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.drop_duplicates()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
data.rename(columns={'#':'ID','Name':'Name','Type 1':'Type_1','Type 2':'Type_2','Total':'Total','HP':'Hp','Attack':'Attack','Defense':'Defense','Sp. Atk':'Sp_Atk','Sp. Def':'Sp_Atk','Speed':'Speed'},inplace=True)

# %%
data
# Out:
#       ID                   Name   Type_1  Type_2  Total  Hp  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type_1      800 non-null    object
#  3   Type_2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   Hp          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp_Atk      800 non-null    int64
#  9   Sp_Atk      800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# How are Pokemon numbers distributed across generations?

# %%
POKEMON_COUNT_BY_GENERATION=data.groupby('Generation')['ID'].count()

# %%
pd.DataFrame(POKEMON_COUNT_BY_GENERATION)
# Out:
#              ID
# Generation
# 1           166
# 2           106
# 3           160
# 4           121
# 5           165
# 6            82

# %% [markdown]
# What are the most common types of Pokemon?

# %%
TYPES=pd.concat([data['Type_1'],data['Type_2']]).value_counts()#combine the type1 ang type2 columns into single column

most_common_types=TYPES#get the most common types of pokemon
print(most_common_types)
# Out:
# Water       126
# Normal      102
# Flying      101
# Grass        95
# Psychic      90
# Bug          72
# Ground       67
# Fire         64
# Poison       62
# Rock         58
# Fighting     53
# Dark         51
# Electric     50
# Dragon       50
# Steel        49
# Ghost        46
# Fairy        40
# Ice          38
# dtype: int64

# %% [markdown]
# What are the strongest and weakest Pokemon species?

# %%
strongest_pokemon=data.sort_values('Total',ascending=False)#find the strongest pokemon species by sorting total columns

weakest_pokemon=data.sort_values('Total')

print('strongest pokemon species:',strongest_pokemon[['Total','Name']])
print('weakest pokemon species:',weakest_pokemon[['Total','Name']])
# Out:
# strongest pokemon species:      Total                   Name
# 426    780  RayquazaMega Rayquaza
# 164    780    MewtwoMega Mewtwo Y
# 163    780    MewtwoMega Mewtwo X
# 422    770    KyogrePrimal Kyogre
# 424    770  GroudonPrimal Groudon
# ..     ...                    ...
# 13     195               Caterpie
# 288    195                Wurmple
# 446    194              Kricketot
# 322    190                Azurill
# 206    180                Sunkern
#
# [800 rows x 2 columns]
# weakest pokemon species:      Total                   Name
# 206    180                Sunkern
# 322    190                Azurill
# 446    194              Kricketot
# 288    195                Wurmple
# 16     195                 Weedle
# ..     ...                    ...
# 424    770  GroudonPrimal Groudon
# 422    770    KyogrePrimal Kyogre
# 164    780    MewtwoMega Mewtwo Y
# 426    780  RayquazaMega Rayquaza
# 163    780    MewtwoMega Mewtwo X
#
# [800 rows x 2 columns]

# %%
strongest_pokemon_4=data.loc[data['Total'].idxmax(),'Name']#find the strongest pokemon species by sorting total columns

weakest_pokemon_5=data.loc[data['Total'].idxmin(),'Name']

print('strongest pokemon species:',strongest_pokemon_4)
print('weakest pokemon species:',weakest_pokemon_5)
# Out:
# strongest pokemon species: MewtwoMega Mewtwo X
# weakest pokemon species: Sunkern

# %% [markdown]
# What are the strongest and weakest types of Pokemon?

# %%
type_stats=data.groupby('Type_1')['Total'].mean()#group the pokemon by their typestats and calculate the avg total for each type

strongest_type=type_stats.idxmax()

weakest_type=type_stats.idxmin()

print('strongest type of pokemon:',strongest_type)
print('weakest type of pokeman:',weakest_type)
# Out:
# strongest type of pokemon: Dragon
# weakest type of pokeman: Bug

# %% [markdown]
# Do any types of Pokemon excel at certain statistics over others?

# %%
TYPES_OF_POKEMON=data.groupby('Type_1')[['Attack','Defense','Speed','Sp_Atk','Sp_Atk']].mean()#group the pokemon by their types and calculate the average of the desured statistic
strongest_type1=TYPES_OF_POKEMON.idxmax()
print('the type that excel is:',strongest_type1)
# Out:
# the type that excel is: Attack      Dragon
# Defense      Steel
# Speed       Flying
# Sp_Atk     Psychic
# Sp_Atk      Dragon
# Sp_Atk     Psychic
# Sp_Atk      Dragon
# dtype: object

# %% [markdown]
# Are any of the statistics correlated?

# %%
correlation_matrix=data[['Hp','Attack','Defense','Sp_Atk','Sp_Atk','Speed']].corr()

print(correlation_matrix)
# Out:
#                Hp    Attack   Defense    Sp_Atk    Sp_Atk    Sp_Atk    Sp_Atk  \
# Hp       1.000000  0.422386  0.239622  0.362380  0.378718  0.362380  0.378718
# Attack   0.422386  1.000000  0.438687  0.396362  0.263990  0.396362  0.263990
# Defense  0.239622  0.438687  1.000000  0.223549  0.510747  0.223549  0.510747
# Sp_Atk   0.362380  0.396362  0.223549  1.000000  0.506121  1.000000  0.506121
# Sp_Atk   0.378718  0.263990  0.510747  0.506121  1.000000  0.506121  1.000000
# Sp_Atk   0.362380  0.396362  0.223549  1.000000  0.506121  1.000000  0.506121
# Sp_Atk   0.378718  0.263990  0.510747  0.506121  1.000000  0.506121  1.000000
# Speed    0.175952  0.381240  0.015227  0.473018  0.259133  0.473018  0.259133
#
#             Speed
# Hp       0.175952
# Attack   0.381240
# Defense  0.015227
# Sp_Atk   0.473018
# Sp_Atk   0.259133
# Sp_Atk   0.473018
# Sp_Atk   0.259133
# Speed    1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %% [markdown]
# Create a training/test split?

# %%
from sklearn.model_selection import train_test_split

features=data[['Hp','Attack','Defense','Sp_Atk','Sp_Atk','Sp_Atk','Sp_Atk','Speed']]#specify the features and target variable 
target=data['Type_1']

X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=42)#split the data into training and test sets

print("Training set size:",len(X_train))
print("Test set size:",len(X_test))
# Out:
# Training set size: 640
# Test set size: 160

# %% [markdown]
# split data into Train and model sets?

# %%
from sklearn.model_selection import train_test_split

features=data[['Hp','Attack','Defense','Sp_Atk','Sp_Atk','Sp_Atk','Sp_Atk','Speed']]#specify the features and target variable 
target=data['Type_1']

X_train,X_model,y_train,y_model=train_test_split(features,target,test_size=0.2,random_state=42)#split the data into training and model sets

print("Training set size:",len(X_train))
print("model set size:",len(X_model))
# Out:
# Training set size: 640
# model set size: 160

# %%
X=data[['Hp','Attack','Defense','Sp_Atk','Sp_Atk','Sp_Atk','Sp_Atk','Speed']]#specify the features and target variable 
y=data['Type_1']

X_train,X_model,y_train,y_model=train_test_split(X,y,test_size=0.2,random_state=101)

from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

model.fit(X_train,y_train)
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array(['Water', 'Grass', 'Water', 'Water', 'Normal', 'Bug', 'Water',
#        'Steel', 'Water', 'Steel', 'Normal', 'Normal', 'Psychic', 'Water',
#        'Steel', 'Water', 'Psychic', 'Water', 'Water', 'Fighting', 'Rock',
#        'Rock', 'Water', 'Psychic', 'Normal', 'Normal', 'Normal', 'Water',
#        'Water', 'Water', 'Psychic', 'Psychic', 'Normal', 'Water', 'Water',
#        'Psychic', 'Water', 'Water', 'Dragon', 'Water', 'Normal', 'Normal',
#        'Water', 'Steel', 'Normal', 'Psychic', 'Water', 'Water', 'Bug',
#        'Water', 'Water', 'Normal', 'Water', 'Water', 'Bug', 'Fire',
#        'Water', 'Steel', 'Normal', 'Water', 'Water', 'Psychic', 'Normal',
#        'Psychic', 'Normal', 'Fire', 'Water', 'Rock', 'Psychic', 'Water',
#        'Water', 'Water', 'Steel', 'Rock', 'Electric', 'Water', 'Bug',
#        'Rock', 'Fighting', 'Normal', 'Electric', 'Rock', 'Normal',
#        'Water', 'Normal', 'Water', 'Bug', 'Electric', 'Normal', 'Normal',
# ...

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.1875
