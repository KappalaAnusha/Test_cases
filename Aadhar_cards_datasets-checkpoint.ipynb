# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/admin/Downloads/11.AADHAR.csv",low_memory=False)

# %%
data
# Out:
#                                              Registrar  \
# 0                                       Allahabad Bank
# 1                                       Allahabad Bank
# 2                                       Allahabad Bank
# 3                                       Allahabad Bank
# 4                                       Allahabad Bank
# ...                                                ...
# 440813  Women and Child Development Govt. of Jharkhand
# 440814  Women and Child Development Govt. of Jharkhand
# 440815  Women and Child Development Govt. of Jharkhand
# 440816  Women and Child Development Govt. of Jharkhand
# 440817  Women and Child Development Govt. of Jharkhand
#
#                            Enrolment Agency          State   District  \
# 0                     A-Onerealtors Pvt Ltd  Uttar Pradesh  Allahabad
# 1              Asha Security Guard Services  Uttar Pradesh  Sonbhadra
# 2                         SGS INDIA PVT LTD  Uttar Pradesh  Sultanpur
# ...

# %%
data.drop_duplicates()
# Out:
#                                              Registrar  \
# 0                                       Allahabad Bank
# 1                                       Allahabad Bank
# 2                                       Allahabad Bank
# 3                                       Allahabad Bank
# 4                                       Allahabad Bank
# ...                                                ...
# 440813  Women and Child Development Govt. of Jharkhand
# 440814  Women and Child Development Govt. of Jharkhand
# 440815  Women and Child Development Govt. of Jharkhand
# 440816  Women and Child Development Govt. of Jharkhand
# 440817  Women and Child Development Govt. of Jharkhand
#
#                            Enrolment Agency          State   District  \
# 0                     A-Onerealtors Pvt Ltd  Uttar Pradesh  Allahabad
# 1              Asha Security Guard Services  Uttar Pradesh  Sonbhadra
# 2                         SGS INDIA PVT LTD  Uttar Pradesh  Sultanpur
# ...

# %%
data.dropna()
# Out:
#                                              Registrar  \
# 0                                       Allahabad Bank
# 1                                       Allahabad Bank
# 2                                       Allahabad Bank
# 3                                       Allahabad Bank
# 4                                       Allahabad Bank
# ...                                                ...
# 440813  Women and Child Development Govt. of Jharkhand
# 440814  Women and Child Development Govt. of Jharkhand
# 440815  Women and Child Development Govt. of Jharkhand
# 440816  Women and Child Development Govt. of Jharkhand
# 440817  Women and Child Development Govt. of Jharkhand
#
#                            Enrolment Agency          State   District  \
# 0                     A-Onerealtors Pvt Ltd  Uttar Pradesh  Allahabad
# 1              Asha Security Guard Services  Uttar Pradesh  Sonbhadra
# 2                         SGS INDIA PVT LTD  Uttar Pradesh  Sultanpur
# ...

# %%
data.columns
# Out:
# Index(['Registrar', 'Enrolment Agency', 'State', 'District', 'Sub District',
#        'Pin Code', 'Gender', 'Age', 'Aadhaar generated', 'Enrolment Rejected',
#        'Residents providing email', 'Residents providing mobile number'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440818 entries, 0 to 440817
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Registrar                          440818 non-null  object
#  1   Enrolment Agency                   440818 non-null  object
#  2   State                              440818 non-null  object
#  3   District                           440818 non-null  object
#  4   Sub District                       440818 non-null  object
#  5   Pin Code                           440818 non-null  object
#  6   Gender                             440818 non-null  object
#  7   Age                                440818 non-null  int64
#  8   Aadhaar generated                  440818 non-null  int64
#  9   Enrolment Rejected                 440818 non-null  int64
#  10  Residents providing email          440818 non-null  int64
# ...

# %% [markdown]
# Find out the total number of cards approved by States.

# %%
approved_cards_bystates=data.groupby('State')['Aadhaar generated'].sum()

# %%
approved_cards_bystates
# Out:
# State
# Andaman and Nicobar Islands         5
# Andhra Pradesh                   5798
# Arunachal Pradesh                 913
# Assam                            3213
# Bihar                          162607
# Chandigarh                        259
# Chhattisgarh                     6604
# Dadra and Nagar Haveli            140
# Daman and Diu                     105
# Delhi                            8426
# Goa                              1167
# Gujarat                         34844
# Haryana                          6804
# Himachal Pradesh                 1547
# Jammu and Kashmir                1234
# Jharkhand                        9868
# Karnataka                       19764
# Kerala                          15143
# Lakshadweep                         4
# Madhya Pradesh                  53276
# Maharashtra                     26085
# Manipur                          1323
# Meghalaya                         277
# Mizoram                          6279
# ...

# %% [markdown]
# 2.Find out the total number of cards Enrolment rejected by states.

# %%
Rejected_cards_bystates=data.groupby('State')['Enrolment Rejected'].sum()

# %%
approved_cards_bystates
# Out:
# State
# Andaman and Nicobar Islands       2
# Andhra Pradesh                  373
# Arunachal Pradesh                79
# Assam                            28
# Bihar                          7209
# Chandigarh                        9
# Chhattisgarh                    380
# Dadra and Nagar Haveli            3
# Daman and Diu                     2
# Delhi                           591
# Goa                             127
# Gujarat                        2500
# Haryana                         532
# Himachal Pradesh                123
# Jammu and Kashmir               204
# Jharkhand                       477
# Karnataka                      1445
# Kerala                          538
# Lakshadweep                       1
# Madhya Pradesh                 3509
# Maharashtra                    1818
# Manipur                         190
# Meghalaya                         2
# Mizoram                         185
# Nagaland                         43
# Odisha                         1596
# ...

# %% [markdown]
# 3. Find out the total number of cards approved by Districts.

# %%
approved_cards_bydistricts=data.groupby('District')['Aadhaar generated'].sum()

# %%
approved_cards_bydistricts
# Out:
# District
# Adilabad         265
# Agra            2283
# Ahmadnagar       476
# Ahmedabad       4212
# Aizawl          1095
#                 ...
# Wokha             32
# Yadgir           325
# Yamuna Nagar     197
# Yavatmal         712
# Zunheboto          8
# Name: Aadhaar generated, Length: 664, dtype: int64

# %% [markdown]
# 4. Find out the total number of cards rejected by Districts.

# %%
Rejected_cards_bydistrict=data.groupby('District')['Enrolment Rejected'].sum()

# %%
Rejected_cards_bydistrict
# Out:
# District
# Adilabad          7
# Agra            137
# Ahmadnagar       45
# Ahmedabad       278
# Aizawl          111
#                ...
# Wokha             2
# Yadgir           28
# Yamuna Nagar     11
# Yavatmal         78
# Zunheboto         0
# Name: Enrolment Rejected, Length: 664, dtype: int64

# %% [markdown]
# 5.Total Count Gender Based

# %%
gender_counts=data['Gender'].value_counts()

# %%
gender_counts
# Out:
# M    292798
# F    148013
# T         7
# Name: Gender, dtype: int64

# %% [markdown]
# 6.Count Records age <25, age between 25 &35, age>45

# %%
age_less_25=data[data['Age']<25].count()
age_between_25_35=data[(data['Age']>=25)&(data['Age']<=35)].count()
age_greater_than_45=data[data['Age']>45].count()

# %%
age_less_25
# Out:
# Registrar                            296836
# Enrolment Agency                     296836
# State                                296836
# District                             296836
# Sub District                         296836
# Pin Code                             296836
# Gender                               296836
# Age                                  296836
# Aadhaar generated                    296836
# Enrolment Rejected                   296836
# Residents providing email            296836
# Residents providing mobile number    296836
# dtype: int64

# %%
age_between_25_35
# Out:
# Registrar                            62512
# Enrolment Agency                     62512
# State                                62512
# District                             62512
# Sub District                         62512
# Pin Code                             62512
# Gender                               62512
# Age                                  62512
# Aadhaar generated                    62512
# Enrolment Rejected                   62512
# Residents providing email            62512
# Residents providing mobile number    62512
# dtype: int64

# %%
age_greater_than_45
# Out:
# Registrar                            50610
# Enrolment Agency                     50610
# State                                50610
# District                             50610
# Sub District                         50610
# Pin Code                             50610
# Gender                               50610
# Age                                  50610
# Aadhaar generated                    50610
# Enrolment Rejected                   50610
# Residents providing email            50610
# Residents providing mobile number    50610
# dtype: int64
