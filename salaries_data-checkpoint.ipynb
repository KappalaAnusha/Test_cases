# %%
import pandas as pd
import numpy as np

# %%
sal=pd.read_csv("C:/Users/admin/Downloads/Sf_Salaries (1).csv")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9348\874144423.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal=pd.read_csv("C:/Users/admin/Downloads/Sf_Salaries (1).csv")

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
sal.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#errors='coerce'it is helps to handing missing or incorrect data
#errors='coerce'is handle errors when performing operation on data .it allows uus to replace any invaild or provlematic with NaN instead of throwing an error
sal['BasePay']=pd.to_numeric(sal['BasePay'],errors='coerce')
avg_basepay=sal['BasePay'].mean()

# %%
avg_basepay
# Out:
# 66325.4488404877

# %%
sal['OvertimePay']=pd.to_numeric(sal['OvertimePay'],errors='coerce')

# %%
highest_payment=sal['OvertimePay'].max()

# %%
highest_payment
# Out:
# 245131.88

# %%
job_title= sal.loc[sal['EmployeeName']=="JOSEPH DRISCOLL",'JobTitle'].iloc[0]

# %%
job_title
# Out:
# 'CAPTAIN, FIRE SUPPRESSION'

# %%
sal['BasePay']=sal['BasePay'].replace('Not Provided','NaN')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal['OtherPay']=sal['OtherPay'].replace('Not Provided',"NaN")

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal['Benefits']=sal['Benefits'].replace('Not Provided','NaN')

# %%
sal['JobTitle']=sal['JobTitle'].replace('Not Provided','NaN')

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
person_details=sal.loc[sal['EmployeeName']=='JOSEPH DRISCOLL','Benefits']
Benefits=person_details.iloc[0]

# %%
person_details
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %%
person_details
# Out:
# 24    NaN
# Name: Benefits, dtype: object

# %%
sal['totalpay with benefits']=sal['TotalPay'].astype(float)+sal['Benefits'].astype(float)

# %%
highest_paid_person=sal.loc[sal['totalpay with benefits'].idxmax(),'EmployeeName']

# %%
print('the highest_paid _person(including benefits) is:',highest_paid_person)
# Out:
# the highest_paid _person(including benefits) is: David Shinn

# %%
sal['totalpay with benefits']=sal['TotalPay'].astype(float)+sal['Benefits'].astype(float)
highest_paid_person2=sal.loc[sal['totalpay with benefits'].max(),'EmployeeName']
print('the highest_paid _person(including benefits) is:',highest_paid_person2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 2
#       1 sal['totalpay with benefits']=sal['TotalPay'].astype(float)+sal['Benefits'].astype(float)
# ----> 2 highest_paid_person2=sal.loc[sal['totalpay with benefits'].max(),'EmployeeName']
#       3 print('the highest_paid _person(including benefits) is:',highest_paid_person2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1066, in _LocationIndexer.__getitem__(self, key)
#    1064     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065     if self._is_scalar_access(key):
# -> 1066         return self.obj._get_value(*key, takeable=self._takeable)
#    1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#
# ...

# %%
sal['totalpay with benefits']=sal['TotalPay'].astype(float)+sal['Benefits'].astype(float)
lowest_paid_person2=sal.loc[sal['totalpay with benefits'].idxmin(),'EmployeeName']
print('the lowest_paid _person(including benefits) is:',highest_paid_person2)
# Out:
# the lowest_paid _person(including benefits) is: Joe Lopez

# %%
filterd_data=sal[(sal['Year']>=2011)&(sal['Year']<=2014)]
avg_Basepay_peryear=filterd_data.groupby('Year')['BasePay'].mean()

# %%
avg_Basepay_peryear
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
Unique_Job_Tiles=sal['JobTitle'].nunique()

# %%
Unique_Job_Tiles
# Out:
# 2159

# %%
filtered_data1=sal[sal['JobTitle']!='Not provided']
Unique_Job_Title=filtered_data1['JobTitle'].nunique()
print(" the number of unique job title is:",Unique_Job_Title)
# Out:
#  the number of unique job title is: 2158

# %%
filtered_data1=sal[sal['JobTitle']!='Not provided']
top_five_Job_Title=filtered_data1['JobTitle'].value_counts().head(5)
print(" the top five jobs are:",top_five_Job_Title)
# Out:
#  the top five jobs are: Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
